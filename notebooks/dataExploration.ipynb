# %% [markdown]
# 1. Data Exploration and Understanding
#
#     - Load and explore the dataset
#     - Document basic statistics and distributions
#     - Identify potential correlations between features
#     - Create visualizations to communicate findings

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pwd
# Out:
# /Users/dmachuve/Dropbox/Projects/OmdenaSchool/ClimateKIC/week10/machine-learning-assignment-1-group-5/notebooks

# %%
pathdata = "/Users/dmachuve/Dropbox/Projects/OmdenaSchool/ClimateKIC/week10/machine-learning-assignment-1-group-5/data/student_success_dataset.csv"

# %%
#Load the dataset

schooldf = pd.read_csv(pathdata)
schooldf.head()
# Out:
#   student_id  age      gender socioeconomic_status  previous_gpa  \
# 0    STU0001   21  Non-binary                  Low          3.35
# 1    STU0002   19        Male               Middle          4.00
# 2    STU0003   21        Male                  Low          1.72
# 3    STU0004   24  Non-binary               Middle          3.09
# 4    STU0005   19      Female                  Low          2.24
#
#    attendance_rate  participation_score  assignment_completion family_support  \
# 0             0.73                 10.0                   63.8           High
# 1             0.83                  6.2                   45.7         Medium
# 2             0.72                  9.1                   90.3           High
# 3             0.81                  6.5                   58.9           High
# 4             0.83                  9.1                   93.0           High
#
#                             study_resources  study_hours_per_week  \
# ...
